# %% [markdown]
# # Applied Data Science Capstone

# %% [markdown]
# This notebook will be the mainly used for a Capstone Project. The principal objective is passing the course "Applied Data Science".

# %% [markdown]
# ## Assignment week 1: Capstone Project Notebook

# %% [markdown]
# #### Goals:
# <ul>
#     <li> Create a new repository on your Github account and name it Coursera_Capstone.
#     <li> Create a Jupyter Notebook </li>
#        <ul>
#             <li> Write some markdown to explain that this notebook will be mainly used for the capstone project.</li>
#             <li> Import the pandas library as pd.</li>
#             <li> Import the Numpy library as np.</li>
#             <li> Print the following the statement: Hello Capstone Project Course! </li>
#         </ul>
#      </li>
#     <li> Push the Notebook to your Github repository</li>
# </ul>

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np

print ('Hello Capstone Project Course')
# Out:
# Hello Capstone Project Course
